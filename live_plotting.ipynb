# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('output.csv', delim_whitespace = True,header=None)

# %%
df.head()
# Out:
#    0      1      2      3
# 0  0   20.0  180.0  550.4
# 1  1   60.0  184.0  411.1
# 2  2  100.0  188.0  363.0
# 3  3  140.0  192.0  336.7
# 4  4  180.0  196.0  319.9

# %%
fig, ax = plt.subplots(3, 3,figsize=(14,8))
######### row 01 ##########
ax[0,0].plot(df.iloc[0:26,0],df.iloc[0:26,1],'+-r')
ax[0,0].plot(df.iloc[0:26,0],df.iloc[0:26,2],'+-g')
ax[0,0].plot(df.iloc[0:26,0],df.iloc[0:26,3],'+-b')

ax[0,1].plot(df.iloc[26:51,0],df.iloc[26:51,1],'+-r')
ax[0,1].plot(df.iloc[26:51,0],df.iloc[26:51,2],'+-g')
ax[0,1].plot(df.iloc[26:51,0],df.iloc[26:51,3],'+-b')

ax[0,2].plot(df.iloc[51:76,0],df.iloc[51:76,1],'+-r')
ax[0,2].plot(df.iloc[51:76,0],df.iloc[51:76,2],'+-g')
ax[0,2].plot(df.iloc[51:76,0],df.iloc[51:76,3],'+-b')
######### row 02 ##########
ax[1,0].plot(df.iloc[76:101,0],df.iloc[76:101,1],'+-r')
ax[1,0].plot(df.iloc[76:101,0],df.iloc[76:101,2],'+-g')
ax[1,0].plot(df.iloc[76:101,0],df.iloc[76:101,3],'+-b')

ax[1,1].plot(df.iloc[101:126,0],df.iloc[101:126,1],'+-r')
ax[1,1].plot(df.iloc[101:126,0],df.iloc[101:126,2],'+-g')
ax[1,1].plot(df.iloc[101:126,0],df.iloc[101:126,3],'+-b')

ax[1,2].plot(df.iloc[126:151,0],df.iloc[126:151,1],'+-r')
ax[1,2].plot(df.iloc[126:151,0],df.iloc[126:151,2],'+-g')
ax[1,2].plot(df.iloc[126:151,0],df.iloc[126:151,3],'+-b')
######### row 03 ##########
ax[2,0].plot(df.iloc[151:176,0],df.iloc[151:176,1],'+-r')
ax[2,0].plot(df.iloc[151:176,0],df.iloc[151:176,2],'+-g')
ax[2,0].plot(df.iloc[151:176,0],df.iloc[151:176,3],'+-b')

ax[2,1].plot(df.iloc[176:201,0],df.iloc[176:201,1],'+-r')
ax[2,1].plot(df.iloc[176:201,0],df.iloc[176:201,2],'+-g')
ax[2,1].plot(df.iloc[176:201,0],df.iloc[176:201,3],'+-b')

ax[2,2].plot(df.iloc[201:226,0],df.iloc[201:226,1],'+-r')
ax[2,2].plot(df.iloc[201:226,0],df.iloc[201:226,2],'+-g')
ax[2,2].plot(df.iloc[201:226,0],df.iloc[201:226,3],'+-b')

# %%
#df.iloc[26:51]
#df.iloc[51:76]
#df.iloc[76:101]
#df.iloc[101:126]
#df.iloc[126:151]
#df.iloc[151:176]
#df.iloc[176:201]
#df.iloc[201:226]

# %%
# %pylab inline
import time
from IPython.display import clear_output
# Out:
# Matplotlib is building the font cache using fc-list. This may take a moment.
# Populating the interactive namespace from numpy and matplotlib

# %%
# filename of file written by your model
fname = "/home/f/Felix.Goedde/Dokumente/aap/ws_20_21/model_aap_20/tests/c_output.txt"

# %%
# IMPORTANT: there has to exist a file with the above name bevore you start this code cell!
# This file does not have to contain useful content, but should not thorow an error when its read in and plotted!
# You can achieve this by either first starting your c-program and start python afterwards, or you manually create a 
# file with appropriate content

while True:
    try:
        # load all your data here
        z, T = np.loadtxt(fname, unpack=True, delimiter=",")
    except:
        pass
    clear_output(wait=True)
    # create all your plots here
    plt.figure()
    plt.plot(T,z, "-o") 
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-75075429a756> in <module>
#      13     # create all your plots here
#      14     plt.figure()
# ---> 15     plt.plot(T,z, "-o")
#      16     plt.show()
#      17
#
# NameError: name 'T' is not defined
